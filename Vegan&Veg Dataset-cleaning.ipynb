# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("C:/Users/vidhi/Downloads/Datafiniti_Vegetarian_and_Vegan_Restaurants.csv")

# %%
data.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 1  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 2  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 3  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 4  AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
#
#               address                                         categories  \
# 0  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 1  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 2  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 3  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
# 4  1045 San Pablo Ave  Restaurant,Asian/Pacific,Cafe,Vegetarian / Veg...
#
#                primaryCategories    city claimed country  \
# ...

# %%
data.tail()
# Out:
#                         id             dateAdded           dateUpdated  \
# 9995  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9996  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9997  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9998  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
#
#                address                                         categories  \
# 9995  1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9996  1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9997  1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9998  1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
# 9999  1335 W Thomas Rd  Vegetarian / Vegan Restaurant,Restaurant,Medit...
#
#                   primaryCategories     city claimed country  \
# ...

# %%
data.shape
# Out:
# (10000, 47)

# %%
data.replace({"?":np.nan,"--":np.nan}, inplace=True)
data
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 1     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 2     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 3     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# 4     AVwd3yXEkufWRAb59-sH  2016-04-22T02:47:48Z  2018-09-10T21:00:49Z
# ...                    ...                   ...                   ...
# 9995  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9996  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9997  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9998  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
# 9999  AVwd88lK_7pvs4fz-toI  2016-03-28T05:35:40Z  2018-01-09T08:01:08Z
#
#                  address                                         categories  \
# ...

# %%
data.isnull().sum()
# Out:
# id                             0
# dateAdded                      0
# dateUpdated                    0
# address                        0
# categories                     0
# primaryCategories              0
# city                           0
# claimed                     9311
# country                        0
# cuisines                       0
# descriptions.dateSeen      10000
# descriptions.sourceURLs    10000
# descriptions.value         10000
# facebookPageURL             9063
# features.key               10000
# features.value             10000
# hours.day                  10000
# hours.dept                 10000
# hours.hour                 10000
# imageURLs                   4866
# isClosed                    9963
# keys                           0
# languagesSpoken            10000
# latitude                       0
# longitude                      0
# menuPageURL                    0
# menus.amountMax                0
# menus.amountMin                0
# ...

# %%
#column deletion with all null values, axis=1 is for column while axis=0 is for rows
data.drop(['descriptions.sourceURLs','descriptions.value','features.key','features.value'],axis=1, inplace=True)

# %%
data.shape
# Out:
# (10000, 43)

# %%
data.drop(['hours.day','hours.dept','hours.hour','languagesSpoken'],axis=1,inplace=True)

# %%
data.dropna(axis=0, how="all", inplace=True)
data.shape
# Out:
# (10000, 39)

# %%
#this means that there were no rows which had all values missing

# %%
data['claimed'].value_counts() 
#there are 689 values present in the entire dataset out of 100000 values so 6.89% values are present
# we can afford to delete this column
# Out:
# yellowpages.com    369
# foursquare.com     320
# Name: claimed, dtype: int64

# %%
del data['claimed']

# %%
data.drop(['facebookPageURL','imageURLs','menus.category','menus.description','paymentTypes','priceRangeCurrency','priceRangeMin','priceRangeMax','sic','twitter','websites'],axis=1,inplace=True)

# %%
del data['isClosed']

# %%
del data['yearOpened']

# %%
data['menus.currency'].value_counts()
# Out:
# USD    9947
# Name: menus.currency, dtype: int64

# %%
data['menus.currency']
# Out:
# 0       USD
# 1       USD
# 2       USD
# 3       USD
# 4       USD
#        ...
# 9995    USD
# 9996    USD
# 9997    USD
# 9998    USD
# 9999    USD
# Name: menus.currency, Length: 10000, dtype: object

# %%
data.isnull().sum()
# Out:
# id                           0
# dateAdded                    0
# dateUpdated                  0
# address                      0
# categories                   0
# primaryCategories            0
# city                         0
# country                      0
# cuisines                     0
# descriptions.dateSeen    10000
# keys                         0
# latitude                     0
# longitude                    0
# menuPageURL                  0
# menus.amountMax              0
# menus.amountMin              0
# menus.currency              53
# menus.dateSeen               0
# menus.name                   0
# menus.sourceURLs             0
# name                         0
# phones                       0
# postalCode                   0
# province                     0
# sourceURLs                   0
# dtype: int64

# %%
data['menus.currency'].replace({np.nan:"USD"},inplace=True)

# %%
data['menus.currency'].isnull().sum()
# Out:
# 0

# %%
data.to_csv("C:/Users/vidhi/Downloads/Vegetarian_and_Vegan_Restaurants_cleaned.csv",index=False,header=True)

# %%
data['categories'].nunique()
# Out:
# 166

# %%
data['categories'].value_counts()
# Out:
# Chinese Restaurant,Restaurant,Cocktails,Vegetarian,Dim Sum,Chinese,Dim Sum Restaurant                                                                                                                             375
# Restaurant,Vegetarian,Indian                                                                                                                                                                                      349
# Restaurant,Coffee Shops,Beverages Wholesale & Manufacturers,Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian / Vegan Restaurant,Vegetarian,Juice Bar,Vegetarian Restaurants,Healthy,Restaurants    310
# Restaurant,Hotels and motels,American Restaurant,American restaurants,Restaurants                                                                                                                                 308
# ...

# %%
data['primaryCategories'].value_counts()
# Out:
# Accommodation & Food Services                                  9248
# Wholesale Trade,Accommodation & Food Services,Manufacturing     310
# Wholesale Trade,Accommodation & Food Services                   188
# Retail                                                          169
# Arts Entertainment & Recreation                                  65
# Accommodation & Food Services,Information                        20
# Name: primaryCategories, dtype: int64

# %%
data['cuisines'].value_counts()
# Out:
# Vegetarian,Indian                                                                                                       579
# Cocktails,Vegetarian,Dim Sum,Chinese                                                                                    375
# Local/Organic,Vegan Restaurants,Smoothies and Juices,Vegetarian,Healthy                                                 310
# New American,Traditional American,American,Vegetarian Friendly,Gluten Free Options,Vegan Options,Northwest, American    308
# Vegetarian,Dim Sum,Chinese                                                                                              265
#                                                                                                                        ...
# Thai,Asian/Pacific,Vegetarian                                                                                             5
# ...

# %%
data.country.value_counts()
# Out:
# US    10000
# Name: country, dtype: int64

# %%
data.menuPageURL.value_counts()
# Out:
# http://www.menupages.com/restaurants/hakkasan/menu                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             375
# ...
